# %%
import numpy as np

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Hp'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 3AE1-5CA1
#
#  Directory of C:\Users\Hp
#
# 11-02-2022  20:26    <DIR>          .
# 22-01-2022  15:01    <DIR>          ..
# 29-01-2022  23:48               428 .bash_history
# 11-02-2022  20:28    <DIR>          .conda
# 22-01-2022  16:42                25 .condarc
# 22-01-2022  16:42    <DIR>          .continuum
# 29-01-2022  22:16               153 .gitconfig
# 10-02-2022  14:45    <DIR>          .ipynb_checkpoints
# 26-01-2022  21:12    <DIR>          .ipython
# 27-01-2022  12:57    <DIR>          .jupyter
# 29-01-2022  22:50                20 .lesshst
# 11-02-2022  15:54    <DIR>          .matplotlib
# 22-01-2022  16:47    <DIR>          .vscode
# 10-02-2022  13:08    <DIR>          anaconda3
# 21-09-2021  04:33    <DIR>          Contacts
# 10-02-2022  13:12    <DIR>          Desktop
# 23-01-2022  16:39    <DIR>          Documents
# 11-02-2022  14:35    <DIR>          Downloads
# ...

# %%
df = pd.read_csv('C:\\Users\\Hp\\Desktop\\StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#QUESTION 1
avg_score = df.groupby('gender').mean()

# %%
avg_score
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
#QUESTION 2
df_male = df[(df['gender'] == "male") & (df['math score'] > 80) & (df['reading score'] >85) & (df['parental level of education'] == "bachelor's degree")]

# %%
df_male
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 551   male        group B           bachelor's degree  free/reduced
# 562   male        group C           bachelor's degree      standard
# 571   male        group A           bachelor's degree      standard
# 612   male        group C           bachelor's degree      standard
# 916   male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 551               completed          87             90             88
# 562               completed          96             90             92
# 571                    none          91             96             92
# 612               completed          94             90             91
# 916               completed         100            100            100

# %%
total_males = df[(df['gender'] == "male") & (df['parental level of education'] == "bachelor's degree")]

# %%
total_males
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 24    male        group D           bachelor's degree  free/reduced
# 60    male        group E           bachelor's degree  free/reduced
# 77    male        group A           bachelor's degree      standard
# 101   male        group D           bachelor's degree      standard
# 134   male        group D           bachelor's degree  free/reduced
# 135   male        group C           bachelor's degree      standard
# 151   male        group A           bachelor's degree      standard
# 153   male        group D           bachelor's degree      standard
# 206   male        group E           bachelor's degree      standard
# 234   male        group C           bachelor's degree      standard
# 236   male        group D           bachelor's degree  free/reduced
# 270   male        group C           bachelor's degree      standard
# 275   male        group C           bachelor's degree      standard
# ...

# %%
x = len(df_male)

# %%
x
# Out:
# 5

# %%
y = len(total_males)

# %%
y
# Out:
# 55

# %%
percent_male = (x/y *100)

# %%
percent_male
# Out:
# 9.090909090909092

# %%
#QUESTION 3

# %%
males_groupE = df[(df['gender'] == "male") & (df['race/ethnicity'] == "group E")]

# %%
males_groupE
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 34    male        group E                some college      standard
# 35    male        group E          associate's degree      standard
# 50    male        group E                some college      standard
# 51    male        group E          associate's degree  free/reduced
# 60    male        group E           bachelor's degree  free/reduced
# ..     ...            ...                         ...           ...
# 928   male        group E          associate's degree  free/reduced
# 950   male        group E                 high school      standard
# 955   male        group E          associate's degree      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 34                     none          97             87             82
# ...

# %%
male_counts = males_groupE[(males_groupE['parental level of education'] == "high school") | (males_groupE['parental level of education'] == "bachelor's degree")]

# %%
len(male_counts)
# Out:
# 18

# %%
#question 4
import matplotlib.pyplot as plt

# %%
maxi_val = df.groupby('race/ethnicity').max()
plot_4 = maxi_val[['math score','reading score','writing score']]
plot_4
# Out:
#                 math score  reading score  writing score
# race/ethnicity
# group A                100            100             97
# group B                 97             97             96
# group C                 98            100            100
# group D                100            100            100
# group E                100            100            100

# %%
plot_4.plot.bar()
# Out:
# <AxesSubplot:xlabel='race/ethnicity'>

# %%
#question 5

# %%
Male_df = df[df['gender'] == 'male']
Male_df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
Female_df = df[df['gender'] == 'female']
Female_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_Male_none = Male_df[Male_df['test preparation course'] == 'none']
df_Male_comp = Male_df[Male_df['test preparation course'] == 'completed']
data = [['prepared',df_Male_comp['gender'].count()],['not prepared',df_Male_none['gender'].count()]]
df_q5 = pd.DataFrame(data,columns = ['Test Prep','Number'])
df_q5
# Out:
#       Test Prep  Number
# 0      prepared     174
# 1  not prepared     308

# %%
df_q5.plot(x='Test Prep', y='Number', kind ='bar')
# Out:
# <AxesSubplot:xlabel='Test Prep'>

# %%
df_Female_none = Female_df[Female_df['test preparation course'] == 'none']
df_Female_comp = Female_df[Female_df['test preparation course'] == 'completed']
data1 = [['prepared',df_Female_comp['gender'].count()],['not prepared',df_Female_none['gender'].count()]]
Df_q5 = pd.DataFrame(data1,columns = ['Test Prep','Number'])
Df_q5
# Out:
#       Test Prep  Number
# 0      prepared     184
# 1  not prepared     334

# %%
Df_q5.plot(x='Test Prep', y='Number', kind ='bar')
# Out:
# <AxesSubplot:xlabel='Test Prep'>
